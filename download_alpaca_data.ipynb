# %%
import urllib.request

url = "https://raw.githubusercontent.com/tatsu-lab/stanford_alpaca/main/alpaca_data.json"
print("Sohbet veri seti (Alpaca) indiriliyor, lütfen bekleyin...")

# Dosyayı doğrudan ana klasöre çeker
urllib.request.urlretrieve(url, "alpaca_data.json")

print("alpaca_data.json başarıyla klasörüne indi! İnterneti kapatabilirsin.")
# Out:
# Sohbet veri seti (Alpaca) indiriliyor, lütfen bekleyin...
# ✅ alpaca_data.json başarıyla klasörüne indi! İnterneti kapatabilirsin.
